# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd 
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm


from sklearn.metrics import mean_squared_error, r2_score
import os

# %%
train = pd.read_csv('train_prepared.csv', index_col=[0], parse_dates=[0])
#test = pd.read_csv('test_prepared.csv', index_col=[0], parse_dates=[0])

train.head()
# Out:
#             Passengers  year  month  dayofmonth  quarter  dayofyear  \
# Month
# 1949-01-01         112  1949      1           1        1          1
# 1949-02-01         118  1949      2           1        1         32
# 1949-03-01         132  1949      3           1        1         60
# 1949-04-01         129  1949      4           1        2         91
# 1949-05-01         121  1949      5           1        2        121
#
#             weekofyear  dayofweek  hour     t1     t2     t3    exp_0_01  \
# Month
# 1949-01-01          53          5     0    0.0    0.0    0.0  112.000000
# 1949-02-01           5          1     0  112.0    0.0    0.0  112.060000
# 1949-03-01           9          1     0  118.0  112.0    0.0  112.259400
# 1949-04-01          13          4     0  132.0  118.0  112.0  112.426806
# 1949-05-01          17          6     0  129.0  132.0  118.0  112.512538
#
#               exp_0_03    exp_0_08
# Month
# 1949-01-01  112.000000  112.000000
# 1949-02-01  112.180000  112.480000
# 1949-03-01  112.774600  114.041600
# 1949-04-01  113.261362  115.238272
# 1949-05-01  113.493521  115.699210

# %%
ts = train['Passengers']
plt.figure(figsize=(12, 10))
plt.plot(ts)

# %%
fig = plt.figure(figsize=(12, 10))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(ts, lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(ts, lags=40, ax=ax2)
# Out:
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1406: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
plt.figure(figsize=(12, 10))
ts_log = np.log1p(ts)
plt.plot(ts_log)

# %%
plt.figure(figsize=(12, 10))
ma = ts_log.rolling(12).mean()
plt.plot(ts_log)
plt.plot(ma)

# %%
plt.figure(figsize=(12, 10))
ts_log_ma_diff = ts_log-ma
ts_log_ma_diff.dropna(inplace=True)
plt.plot(ts_log_ma_diff)

# %%
plt.figure(figsize=(12, 10))
exp_avg = ts_log.ewm(12).mean()
plt.plot(ts_log)
plt.plot(exp_avg)

# %%
plt.figure(figsize=(12, 10))
ts_log_ewma_diff = ts_log-exp_avg
ts_log_ewma_diff.dropna(inplace=True)
plt.plot(ts_log_ewma_diff)

# %%
plt.figure(figsize=(12, 10))
ts_log_diff = ts_log - ts_log.shift()
ts_log_diff.dropna(inplace=True)
plt.plot(ts_log_diff)

# %%
from statsmodels.tsa.stattools import adfuller

def test_ts_stationarity(ts):
    ma = ts.rolling(12).mean()
    std = ts.rolling(12).std()
    plt.figure(figsize=(12, 10))
    orig = plt.plot(ts, color='blue', label='Original')
    mean = plt.plot(ma, color='red', label='Rolling mean')
    std = plt.plot(std, color='black', label='Rolling std')
    plt.legend(loc='best')
    plt.title("Rolling mean & std")
    plt.show()
    #adf test
    print("Results of DF test:")
    dftest = adfuller(ts, autolag='AIC')
    df_test = pd.DataFrame(dftest[:-1])
    df_test.index = ['Test statistic', 'p_value', 'lags', 'num observations', 'critical values']
    print(df_test)

# %%
test_ts_stationarity(ts)
# Out:
# Results of DF test:
#                                                                   0
# Test statistic                                             0.536756
# p_value                                                    0.985948
# lags                                                             13
# num observations                                                116
# critical values   {'1%': -3.4880216384691867, '5%': -2.886796686...

# %%
test_ts_stationarity(ts_log_ewma_diff)
# Out:
# Results of DF test:
#                                                                   0
# Test statistic                                             -3.37852
# p_value                                                   0.0117134
# lags                                                             13
# num observations                                                116
# critical values   {'1%': -3.4880216384691867, '5%': -2.886796686...

# %%
test_ts_stationarity(ts_log_diff)
# Out:
# Results of DF test:
#                                                                   0
# Test statistic                                             -2.86168
# p_value                                                   0.0499885
# lags                                                             12
# num observations                                                116
# critical values   {'1%': -3.4880216384691867, '5%': -2.886796686...

# %%
test_ts_stationarity(ts_log_ma_diff)
# Out:
# Results of DF test:
#                                                                   0
# Test statistic                                             -3.00126
# p_value                                                   0.0347767
# lags                                                             13
# num observations                                                105
# critical values   {'1%': -3.4942202045135513, '5%': -2.889485291...

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

dec = seasonal_decompose(ts_log)
trend = dec.trend
seasonal = dec.seasonal
residuals = dec.resid

plt.figure(figsize=(12,10))
plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.subplot(413)
plt.plot(seasonal, label='Seasonal')
plt.subplot(414)
plt.plot(residuals, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %%
test_ts_stationarity(residuals.dropna())
# Out:
# Results of DF test:
#                                                                   0
# Test statistic                                             -6.74365
# p_value                                                 3.07365e-09
# lags                                                              7
# num observations                                                110
# critical values   {'1%': -3.4912451337340342, '5%': -2.888195454...

# %%
from statsmodels.tsa.arima_model import ARIMA

model = ARIMA(ts_log, order=(2,1,0))
results_AR = model.fit(disp=-1)
plt.figure(figsize=(10,8))
plt.plot(ts_log_diff)
plt.plot(results_AR.fittedvalues, color='black')
plt.title('RSS: %.4f'%sum((results_AR.fittedvalues-ts_log_diff)**2))
# Out:
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# Text(0.5, 1.0, 'RSS: 1.3394')

# %%
from sklearn.model_selection import TimeSeriesSplit

tscv = TimeSeriesSplit(10)

CV_scores_AR = []
for train_index, test_index in tscv.split(ts_log):
    model = ARIMA(ts_log[train_index], order=(2,1,0))
    results_AR = model.fit(disp=-1)
    preds = results_AR.forecast(steps=len(test_index))
    print(ts_log[test_index])
    CV_scores_AR.append(r2_score(ts_log[test_index], preds[0]))
# Out:
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# Month
# 1950-09-01    5.068904
# 1950-10-01    4.897840
# 1950-11-01    4.744932
# 1950-12-01    4.948760
# 1951-01-01    4.983607
# 1951-02-01    5.017280
# 1951-03-01    5.187386
# 1951-04-01    5.099866
# 1951-05-01    5.153292
# 1951-06-01    5.187386
# 1951-07-01    5.298317
# Name: Passengers, dtype: float64
# Month
# 1951-08-01    5.298317
# 1951-09-01    5.220356
# 1951-10-01    5.093750
# 1951-11-01    4.990433
# 1951-12-01    5.117994
# 1952-01-01    5.147494
# 1952-02-01    5.198497
# 1952-03-01    5.267858
# 1952-04-01    5.204007
# 1952-05-01    5.214936
# 1952-06-01    5.389072
# Name: Passengers, dtype: float64
# Month
# 1952-07-01    5.442418
# 1952-08-01    5.493061
# 1952-09-01    5.347108
# 1952-10-01    5.257495
# 1952-11-01    5.153292
# 1952-12-01    5.273000
# 1953-01-01    5.283204
# 1953-02-01    5.283204
# 1953-03-01    5.468060
# 1953-04-01    5.463832
# 1953-05-01    5.438079
# Name: Passengers, dtype: float64
# Month
# 1953-06-01    5.497168
# 1953-07-01    5.579730
# 1953-08-01    5.609472
# 1953-09-01    5.472271
# 1953-10-01    5.356586
# 1953-11-01    5.198497
# 1953-12-01    5.308268
# 1954-01-01    5.323010
# 1954-02-01    5.241747
# 1954-03-01    5.463832
# 1954-04-01    5.429346
# Name: Passengers, dtype: float64
# Month
# 1954-05-01    5.459586
# 1954-06-01    5.579730
# 1954-07-01    5.713733
# 1954-08-01    5.683580
# 1954-09-01    5.560682
# 1954-10-01    5.438079
# 1954-11-01    5.318120
# 1954-12-01    5.438079
# 1955-01-01    5.493061
# 1955-02-01    5.455321
# 1955-03-01    5.590987
# Name: Passengers, dtype: float64
# Month
# 1955-04-01    5.598422
# 1955-05-01    5.602119
# 1955-06-01    5.755742
# 1955-07-01    5.899897
# 1955-08-01    5.852202
# 1955-09-01    5.746203
# 1955-10-01    5.616771
# 1955-11-01    5.472271
# 1955-12-01    5.631212
# 1956-01-01    5.652489
# 1956-02-01    5.627621
# Name: Passengers, dtype: float64
# Month
# 1956-03-01    5.762051
# 1956-04-01    5.749393
# 1956-05-01    5.765191
# 1956-06-01    5.926926
# 1956-07-01    6.025866
# 1956-08-01    6.006353
# 1956-09-01    5.874931
# 1956-10-01    5.726848
# 1956-11-01    5.605802
# 1956-12-01    5.726848
# 1957-01-01    5.755742
# Name: Passengers, dtype: float64
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# Month
# 1957-02-01    5.710427
# 1957-03-01    5.877736
# 1957-04-01    5.855072
# 1957-05-01    5.874931
# 1957-06-01    6.047372
# 1957-07-01    6.144186
# 1957-08-01    6.148468
# 1957-09-01    6.003887
# 1957-10-01    5.852202
# 1957-11-01    5.723585
# 1957-12-01    5.820083
# Name: Passengers, dtype: float64
# Month
# 1958-01-01    5.831882
# 1958-02-01    5.765191
# 1958-03-01    5.894403
# 1958-04-01    5.855072
# 1958-05-01    5.897154
# 1958-06-01    6.077642
# 1958-07-01    6.198479
# 1958-08-01    6.226537
# 1958-09-01    6.003887
# 1958-10-01    5.886104
# 1958-11-01    5.739793
# Name: Passengers, dtype: float64
# Month
# 1958-12-01    5.823046
# 1959-01-01    5.888878
# 1959-02-01    5.837730
# 1959-03-01    6.008813
# 1959-04-01    5.983936
# 1959-05-01    6.042633
# 1959-06-01    6.159095
# 1959-07-01    6.308098
# 1959-08-01    6.327937
# 1959-09-01    6.139885
# 1959-10-01    6.011267
# Name: Passengers, dtype: float64
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
CV_scores_AR
# Out:
# [-0.7812812728186596,
#  -3.609052196846883,
#  -1.1523852070837801,
#  -1.301457123095302,
#  -0.6058801307973822,
#  -0.28997021493937414,
#  -1.1990031805483743,
#  -0.7002812728644925,
#  0.008623838658209926,
#  -2.0039201437516323]

# %% [markdown]
# Сохраним обученную модель авторегрессии

# %%
import dill

# %%
model = ARIMA(ts_log, order=(2,1,0))
results_AR = model.fit(disp=-1)

with open("./models/AR.model", "wb") as f:
    dill.dump(results_AR, f)
# Out:
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %% [markdown]
# Moving Average

# %%
model = ARIMA(ts_log, order=(0,1,2))
results_AR = model.fit(disp=-1)
plt.figure(figsize=(10,8))
plt.plot(ts_log_diff)
plt.plot(results_AR.fittedvalues, color='black')
plt.title('RSS: %.4f'%sum((results_AR.fittedvalues-ts_log_diff)**2))

tscv = TimeSeriesSplit(10)

CV_scores_MA = []
for train_index, test_index in tscv.split(ts_log):
    model = ARIMA(ts_log[train_index], order=(0,1,2))
    results_AR = model.fit(disp=-1)
    preds = results_AR.forecast(steps=len(test_index))
    print(ts_log[test_index])
    CV_scores_MA.append(r2_score(ts_log[test_index], preds[0]))
# Out:
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# Month
# 1950-09-01    5.068904
# 1950-10-01    4.897840
# 1950-11-01    4.744932
# 1950-12-01    4.948760
# 1951-01-01    4.983607
# 1951-02-01    5.017280
# 1951-03-01    5.187386
# 1951-04-01    5.099866
# 1951-05-01    5.153292
# 1951-06-01    5.187386
# 1951-07-01    5.298317
# Name: Passengers, dtype: float64
# Month
# 1951-08-01    5.298317
# 1951-09-01    5.220356
# 1951-10-01    5.093750
# 1951-11-01    4.990433
# 1951-12-01    5.117994
# 1952-01-01    5.147494
# 1952-02-01    5.198497
# 1952-03-01    5.267858
# 1952-04-01    5.204007
# 1952-05-01    5.214936
# 1952-06-01    5.389072
# Name: Passengers, dtype: float64
# Month
# 1952-07-01    5.442418
# 1952-08-01    5.493061
# 1952-09-01    5.347108
# 1952-10-01    5.257495
# 1952-11-01    5.153292
# 1952-12-01    5.273000
# 1953-01-01    5.283204
# 1953-02-01    5.283204
# 1953-03-01    5.468060
# 1953-04-01    5.463832
# 1953-05-01    5.438079
# Name: Passengers, dtype: float64
# Month
# 1953-06-01    5.497168
# 1953-07-01    5.579730
# 1953-08-01    5.609472
# 1953-09-01    5.472271
# 1953-10-01    5.356586
# 1953-11-01    5.198497
# 1953-12-01    5.308268
# 1954-01-01    5.323010
# 1954-02-01    5.241747
# 1954-03-01    5.463832
# 1954-04-01    5.429346
# Name: Passengers, dtype: float64
# Month
# 1954-05-01    5.459586
# 1954-06-01    5.579730
# 1954-07-01    5.713733
# 1954-08-01    5.683580
# 1954-09-01    5.560682
# 1954-10-01    5.438079
# 1954-11-01    5.318120
# 1954-12-01    5.438079
# 1955-01-01    5.493061
# 1955-02-01    5.455321
# 1955-03-01    5.590987
# Name: Passengers, dtype: float64
# Month
# 1955-04-01    5.598422
# 1955-05-01    5.602119
# 1955-06-01    5.755742
# 1955-07-01    5.899897
# 1955-08-01    5.852202
# 1955-09-01    5.746203
# 1955-10-01    5.616771
# 1955-11-01    5.472271
# 1955-12-01    5.631212
# 1956-01-01    5.652489
# 1956-02-01    5.627621
# Name: Passengers, dtype: float64
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# Month
# 1956-03-01    5.762051
# 1956-04-01    5.749393
# 1956-05-01    5.765191
# 1956-06-01    5.926926
# 1956-07-01    6.025866
# 1956-08-01    6.006353
# 1956-09-01    5.874931
# 1956-10-01    5.726848
# 1956-11-01    5.605802
# 1956-12-01    5.726848
# 1957-01-01    5.755742
# Name: Passengers, dtype: float64
# Month
# 1957-02-01    5.710427
# 1957-03-01    5.877736
# 1957-04-01    5.855072
# 1957-05-01    5.874931
# 1957-06-01    6.047372
# 1957-07-01    6.144186
# 1957-08-01    6.148468
# 1957-09-01    6.003887
# 1957-10-01    5.852202
# 1957-11-01    5.723585
# 1957-12-01    5.820083
# Name: Passengers, dtype: float64
# Month
# 1958-01-01    5.831882
# 1958-02-01    5.765191
# 1958-03-01    5.894403
# 1958-04-01    5.855072
# 1958-05-01    5.897154
# 1958-06-01    6.077642
# 1958-07-01    6.198479
# 1958-08-01    6.226537
# 1958-09-01    6.003887
# 1958-10-01    5.886104
# 1958-11-01    5.739793
# Name: Passengers, dtype: float64
# Month
# 1958-12-01    5.823046
# 1959-01-01    5.888878
# 1959-02-01    5.837730
# 1959-03-01    6.008813
# 1959-04-01    5.983936
# 1959-05-01    6.042633
# 1959-06-01    6.159095
# 1959-07-01    6.308098
# 1959-08-01    6.327937
# 1959-09-01    6.139885
# 1959-10-01    6.011267
# Name: Passengers, dtype: float64
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
CV_scores_MA
# Out:
# [-1.0322712619977095,
#  0.337486062437786,
#  0.08715401532953315,
#  -0.7146374921566898,
#  -0.406142111916751,
#  -0.27527047236062474,
#  -0.2758225066859359,
#  0.042422832132217314,
#  -0.28575851230568183,
#  -1.396553860358182]

# %%
model = ARIMA(ts_log, order=(0,1,2))
results_AR = model.fit(disp=-1)

with open("./models/MA.model", "wb") as f:
    dill.dump(results_AR, f)
# Out:
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %% [markdown]
# ### ARIMA

# %%
model = ARIMA(ts_log, order=(2,1,2))
results_AR = model.fit(disp=-1)
plt.figure(figsize=(10,8))
plt.plot(ts_log_diff)
plt.plot(results_AR.fittedvalues, color='black')
plt.title('RSS: %.4f'%sum((results_AR.fittedvalues-ts_log_diff)**2))

tscv = TimeSeriesSplit(10)

CV_scores_ARIMA = []
for train_index, test_index in tscv.split(ts_log):
    model = ARIMA(ts_log[train_index], order=(2,1,2))
    results_AR = model.fit(disp=-1)
    preds = results_AR.forecast(steps=len(test_index))
    print(ts_log[test_index])
    CV_scores_ARIMA.append(r2_score(ts_log[test_index], preds[0]))
# Out:
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# Month
# 1950-09-01    5.068904
# 1950-10-01    4.897840
# 1950-11-01    4.744932
# 1950-12-01    4.948760
# 1951-01-01    4.983607
# 1951-02-01    5.017280
# 1951-03-01    5.187386
# 1951-04-01    5.099866
# 1951-05-01    5.153292
# 1951-06-01    5.187386
# 1951-07-01    5.298317
# Name: Passengers, dtype: float64
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# Month
# 1951-08-01    5.298317
# 1951-09-01    5.220356
# 1951-10-01    5.093750
# 1951-11-01    4.990433
# 1951-12-01    5.117994
# 1952-01-01    5.147494
# 1952-02-01    5.198497
# 1952-03-01    5.267858
# 1952-04-01    5.204007
# 1952-05-01    5.214936
# 1952-06-01    5.389072
# Name: Passengers, dtype: float64
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# Month
# 1952-07-01    5.442418
# 1952-08-01    5.493061
# 1952-09-01    5.347108
# 1952-10-01    5.257495
# 1952-11-01    5.153292
# 1952-12-01    5.273000
# 1953-01-01    5.283204
# 1953-02-01    5.283204
# 1953-03-01    5.468060
# 1953-04-01    5.463832
# 1953-05-01    5.438079
# Name: Passengers, dtype: float64
# Month
# 1953-06-01    5.497168
# 1953-07-01    5.579730
# 1953-08-01    5.609472
# 1953-09-01    5.472271
# 1953-10-01    5.356586
# 1953-11-01    5.198497
# 1953-12-01    5.308268
# 1954-01-01    5.323010
# 1954-02-01    5.241747
# 1954-03-01    5.463832
# 1954-04-01    5.429346
# Name: Passengers, dtype: float64
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:689: RuntimeWarning: overflow encountered in exp
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:689: RuntimeWarning: invalid value encountered in true_divide
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:690: RuntimeWarning: overflow encountered in exp
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:690: RuntimeWarning: invalid value encountered in true_divide
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# Month
# 1954-05-01    5.459586
# 1954-06-01    5.579730
# 1954-07-01    5.713733
# 1954-08-01    5.683580
# 1954-09-01    5.560682
# 1954-10-01    5.438079
# 1954-11-01    5.318120
# 1954-12-01    5.438079
# 1955-01-01    5.493061
# 1955-02-01    5.455321
# 1955-03-01    5.590987
# Name: Passengers, dtype: float64
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# Month
# 1955-04-01    5.598422
# 1955-05-01    5.602119
# 1955-06-01    5.755742
# 1955-07-01    5.899897
# 1955-08-01    5.852202
# 1955-09-01    5.746203
# 1955-10-01    5.616771
# 1955-11-01    5.472271
# 1955-12-01    5.631212
# 1956-01-01    5.652489
# 1956-02-01    5.627621
# Name: Passengers, dtype: float64
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# Month
# 1956-03-01    5.762051
# 1956-04-01    5.749393
# 1956-05-01    5.765191
# 1956-06-01    5.926926
# 1956-07-01    6.025866
# 1956-08-01    6.006353
# 1956-09-01    5.874931
# 1956-10-01    5.726848
# 1956-11-01    5.605802
# 1956-12-01    5.726848
# 1957-01-01    5.755742
# Name: Passengers, dtype: float64
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# Month
# 1957-02-01    5.710427
# 1957-03-01    5.877736
# 1957-04-01    5.855072
# 1957-05-01    5.874931
# 1957-06-01    6.047372
# 1957-07-01    6.144186
# 1957-08-01    6.148468
# 1957-09-01    6.003887
# 1957-10-01    5.852202
# 1957-11-01    5.723585
# 1957-12-01    5.820083
# Name: Passengers, dtype: float64
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:689: RuntimeWarning: overflow encountered in exp
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:689: RuntimeWarning: invalid value encountered in true_divide
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:690: RuntimeWarning: overflow encountered in exp
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:690: RuntimeWarning: invalid value encountered in true_divide
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# Month
# 1958-01-01    5.831882
# 1958-02-01    5.765191
# 1958-03-01    5.894403
# 1958-04-01    5.855072
# 1958-05-01    5.897154
# 1958-06-01    6.077642
# 1958-07-01    6.198479
# 1958-08-01    6.226537
# 1958-09-01    6.003887
# 1958-10-01    5.886104
# 1958-11-01    5.739793
# Name: Passengers, dtype: float64
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# Month
# 1958-12-01    5.823046
# 1959-01-01    5.888878
# 1959-02-01    5.837730
# 1959-03-01    6.008813
# 1959-04-01    5.983936
# 1959-05-01    6.042633
# 1959-06-01    6.159095
# 1959-07-01    6.308098
# 1959-08-01    6.327937
# 1959-09-01    6.139885
# 1959-10-01    6.011267
# Name: Passengers, dtype: float64

# %%
CV_scores_ARIMA
# Out:
# [-2.204048753394367,
#  0.6173650529898119,
#  0.40526416832886447,
#  -0.7326739572451644,
#  -0.12204352173977218,
#  0.08938099376631081,
#  0.08572704848905521,
#  0.15247294094647512,
#  -0.2957023523881108,
#  0.5182667407507702]

# %%
model = ARIMA(ts_log, order=(2,1,2))
results_AR = model.fit(disp=-1)

with open("./models/ARIMA.model", "wb") as f:
    dill.dump(results_AR, f)
# Out:
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/artemzraev/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %% [markdown]
# Сохраним метрики

# %%
pd.DataFrame({'AR': CV_scores_AR, 
              'MA': CV_scores_MA,
              'ARIMA': CV_scores_ARIMA})
# Out:
#          AR        MA     ARIMA
# 0 -0.781281 -1.032271 -2.204049
# 1 -3.609052  0.337486  0.617365
# 2 -1.152385  0.087154  0.405264
# 3 -1.301457 -0.714637 -0.732674
# 4 -0.605880 -0.406142 -0.122044
# 5 -0.289970 -0.275270  0.089381
# 6 -1.199003 -0.275823  0.085727
# 7 -0.700281  0.042423  0.152473
# 8  0.008624 -0.285759 -0.295702
# 9 -2.003920 -1.396554  0.518267

# %%
pd.DataFrame({'AR': CV_scores_AR, 
              'MA': CV_scores_MA,
              'ARIMA': CV_scores_ARIMA}).to_csv("./models/CV_ARIMA.csv")
